# %% [markdown]
# # Dirty FIFA Dataset Cleaning

# %% [markdown]
# ## Import neccesary requirements`

# %%
import pandas as pd

# %% [markdown]
# ## import dataset using pandas library

# %%
pwd
# Out:
# '/home/zion/Documents/my_jupyter_notebook/FIFA DATA SCI'

# %%
ls
# Out:
# fifa.csv*  FIFA_dataset_cleaning.ipynb  LICENSE  new_Clean_FIFA_dataset.csv

# %%
dataset = pd.read_csv('fifa.csv', low_memory= False)

# %%
dataset.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %% [markdown]
# ### Note : make copy of dataset and keep the original safe for future reference

# %%
# making a copy of the dataset
df = dataset.copy()

# %% [markdown]
# ## Overwiew of the dataset

# %%
df.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %% [markdown]
# ### expand the no of columns displayed to see all of the data

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %%
df.tail()
# Out:
#            ID          Name        LongName  \
# 18974  247223        Xia Ao          Ao Xia
# 18975  258760      B. Hough       Ben Hough
# 18976  252757   R. McKinley  Ronan McKinley
# 18977  243790  Wang Zhen'ao    Zhen'ao Wang
# 18978  252520     Zhou Xiao       Xiao Zhou
#
#                                                photoUrl  \
# 18974  https://cdn.sofifa.com/players/247/223/21_60.png
# 18975  https://cdn.sofifa.com/players/258/760/21_60.png
# 18976  https://cdn.sofifa.com/players/252/757/21_60.png
# 18977  https://cdn.sofifa.com/players/243/790/21_60.png
# 18978  https://cdn.sofifa.com/players/252/520/21_60.png
#
#                                                playerUrl Nationality  Age  \
# 18974     http://sofifa.com/player/247223/ao-xia/210006/    China PR   21
# 18975  http://sofifa.com/player/258760/ben-hough/210006/     England   17
# 18976  http://sofifa.com/player/252757/ronan-mckinley...     England   18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   LongName          18979 non-null  object
#  3   photoUrl          18979 non-null  object
#  4   playerUrl         18979 non-null  object
#  5   Nationality       18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Club              18979 non-null  object
#  10  Contract          18979 non-null  object
#  11  Positions         18979 non-null  object
#  12  Height            18979 non-null  object
#  13  Weight            18979 non-null  object
#  14  Preferred Foot    18979 non-null  object
#  15  BOV               18979 non-null  int64
# ...

# %% [markdown]
# ## Begin Cleaning the Dataset

# %% [markdown]
# ### Change LongName to FullName

# %%
df = df.rename(columns ={'LongName' : 'FullName'})

# %%
df.head(1)
# Out:
#        ID      Name      FullName  \
# 0  158023  L. Messi  Lionel Messi
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
#
#    POT                  Club     Contract   Positions Height Weight  \
# 0   93  \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg
#
#   Preferred Foot  BOV Best Position       Joined Loan Date End    Value  \
# 0           Left   93            RW  Jul 1, 2004           NaN  €103.5M
#
#        Wage Release Clause  Attacking  Crossing  Finishing  Heading Accuracy  \
# 0  €5601000        €138.4M        429        85         95                70
#
#    Short Passing  Volleys  Skill  Dribbling  Curve  FK Accuracy  Long Passing  \
# 0             91       88    470         96     93           94            91
#
# ...

# %% [markdown]
# ### Drop all row duplicetes

# %%
#removing exact row duplicates
b4_removing_duplicates = df.shape[0]
print('b4 removing diplicates')
print(b4_removing_duplicates)

df  = df.drop_duplicates()

after_removing_duplicates = df.shape[0]
print('after removing diplicates')
after_removing_duplicates
# Out:
# b4 removing diplicates
# 18979
# after removing diplicates
# 18979

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   FullName          18979 non-null  object
#  3   photoUrl          18979 non-null  object
#  4   playerUrl         18979 non-null  object
#  5   Nationality       18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Club              18979 non-null  object
#  10  Contract          18979 non-null  object
#  11  Positions         18979 non-null  object
#  12  Height            18979 non-null  object
#  13  Weight            18979 non-null  object
#  14  Preferred Foot    18979 non-null  object
#  15  BOV               18979 non-null  int64
# ...

# %% [markdown]
# ### strip whitespaces from column names

# %%
#strip whitespaces from column names
new_columns = []
for col in df.columns:
    col_clean = col.strip()
    col_clean = col_clean.replace("\u2193", "") #remove the dowm arrow in the OVA colunm name
    new_columns.append(col_clean)
df.columns = new_columns

# %%
df.head()
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33   93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35   92
# ...

# %% [markdown]
# ### Drop photoUrl column since playerUrl alreadey contains the players photo

# %%
df.drop('photoUrl', axis = 1, inplace = True)

# %%
df.head(3)
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
#
#                                            playerUrl Nationality  Age  OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33   93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35   92
# 2  http://sofifa.com/player/200389/jan-oblak/210006/    Slovenia   27   91
#
#    POT                     Club     Contract   Positions Height Weight  \
# 0   93     \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg
# 1   92         \n\n\n\nJuventus  2018 ~ 2022      ST, LW  187cm   83kg
# 2   93  \n\n\n\nAtlético Madrid  2014 ~ 2023          GK  188cm   87kg
#
#   Preferred Foot  BOV Best Position        Joined Loan Date End    Value  \
# ...

# %% [markdown]
# ### Cleaning the Club column

# %%
# removing the uneccesary characters in the club column like \n\n\n\n
df.Club = df.Club.str.strip()

# %%
df.head()
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            playerUrl Nationality  Age  OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33   93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35   92
# 2  http://sofifa.com/player/200389/jan-oblak/210006/    Slovenia   27   91
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium   29   91
# 4  http://sofifa.com/player/190871/neymar-da-silv...      Brazil   28   91
#
#    POT                 Club     Contract   Positions Height Weight  \
# 0   93         FC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg
# ...

# %%
df.shape
#(no of rows, no of columns)
# Out:
# (18979, 76)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 76 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   FullName          18979 non-null  object
#  3   playerUrl         18979 non-null  object
#  4   Nationality       18979 non-null  object
#  5   Age               18979 non-null  int64
#  6   OVA               18979 non-null  int64
#  7   POT               18979 non-null  int64
#  8   Club              18979 non-null  object
#  9   Contract          18979 non-null  object
#  10  Positions         18979 non-null  object
#  11  Height            18979 non-null  object
#  12  Weight            18979 non-null  object
#  13  Preferred Foot    18979 non-null  object
#  14  BOV               18979 non-null  int64
#  15  Best Position     18979 non-null  object
# ...

# %% [markdown]
# ## Handling Null values

# %% [markdown]
# ### the Loan Date End column and Hits column have some null valuea
# #### the Loan Date End column has about 90% null values
# #### the Hits column has about 10% null values
# ##### this means that the Loan Date End column has little to no sugnificance in this dataset and can be dropped
# ##### the Hits cloumn on hte other has a lot of sihnificance inthis dataset due to the amount of non-null values it has , therefore the remaining values need to be added

# %%
# dropping Loan Date End column
df.drop('Loan Date End', axis = 1, inplace = True)

# %%
df.head(1)
# Out:
#        ID      Name      FullName  \
# 0  158023  L. Messi  Lionel Messi
#
#                                            playerUrl Nationality  Age  OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33   93
#
#    POT          Club     Contract   Positions Height Weight Preferred Foot  \
# 0   93  FC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg           Left
#
#    BOV Best Position       Joined    Value      Wage Release Clause  \
# 0   93            RW  Jul 1, 2004  €103.5M  €5601000        €138.4M
#
#    Attacking  Crossing  Finishing  Heading Accuracy  Short Passing  Volleys  \
# 0        429        85         95                70             91       88
#
#    Skill  Dribbling  Curve  FK Accuracy  Long Passing  Ball Control  Movement  \
# 0    470         96     93           94            91            96       451
#
#    Acceleration  Sprint Speed  Agility  Reactions  Balance  Power  Shot Power  \
# ...

# %% [markdown]
# ### Hits column NaN values will be filled with 0 since its the number of times the players profile was viewed

# %%
df.Hits = df.Hits.fillna('0')
df.Hits.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 18979 entries, 0 to 18978
# Series name: Hits
# Non-Null Count  Dtype
# --------------  -----
# 18979 non-null  object
# dtypes: object(1)
# memory usage: 148.4+ KB

# %%
df.head()
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            playerUrl Nationality  Age  OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33   93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35   92
# 2  http://sofifa.com/player/200389/jan-oblak/210006/    Slovenia   27   91
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium   29   91
# 4  http://sofifa.com/player/190871/neymar-da-silv...      Brazil   28   91
#
#    POT                 Club     Contract   Positions Height Weight  \
# 0   93         FC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg
# ...

# %% [markdown]
# ## WF, SM, IR columns all have stars ★ in them and it need to be removed

# %%
# function defined to ease apllication process  
def remove_star(x):
    x = x.replace('★', '')
    return x

# %% [markdown]
# ### apply the function above  to the columns using the apply() method

# %%
df['W/F'] = df['W/F'].apply(remove_star)

# %%
df.IR = df.IR.apply(remove_star)

# %%
df.SM = df.SM.apply(remove_star)

# %%
df.head()
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            playerUrl Nationality  Age  OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33   93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35   92
# 2  http://sofifa.com/player/200389/jan-oblak/210006/    Slovenia   27   91
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium   29   91
# 4  http://sofifa.com/player/190871/neymar-da-silv...      Brazil   28   91
#
#    POT                 Club     Contract   Positions Height Weight  \
# 0   93         FC Barcelona  2004 ~ 2021  RW, ST, CF  170cm   72kg
# ...

# %% [markdown]
# ### Cleaning the Contract column

# %%
df.Contract.unique()
# Out:
# array(['2004 ~ 2021', '2018 ~ 2022', '2014 ~ 2023', '2015 ~ 2023',
#        '2017 ~ 2022', '2017 ~ 2023', '2018 ~ 2024', '2014 ~ 2022',
#        '2018 ~ 2023', '2016 ~ 2023', '2013 ~ 2023', '2011 ~ 2023',
#        '2009 ~ 2022', '2005 ~ 2021', '2011 ~ 2021', '2015 ~ 2022',
#        '2017 ~ 2024', '2010 ~ 2024', '2012 ~ 2021', '2019 ~ 2024',
#        '2015 ~ 2024', '2017 ~ 2025', '2020 ~ 2025', '2019 ~ 2023',
#        '2008 ~ 2023', '2015 ~ 2021', '2020 ~ 2022', '2012 ~ 2022',
#        '2016 ~ 2025', '2013 ~ 2022', '2011 ~ 2022', '2012 ~ 2024',
#        '2016 ~ 2021', '2012 ~ 2023', '2008 ~ 2022', '2019 ~ 2022',
#        '2017 ~ 2021', '2013 ~ 2024', '2020 ~ 2024', '2010 ~ 2022',
#        '2020 ~ 2021', '2011 ~ 2024', '2020 ~ 2023', '2014 ~ 2024',
#        '2013 ~ 2026', '2016 ~ 2022', '2010 ~ 2021', '2013 ~ 2021',
#        '2019 ~ 2025', '2018 ~ 2025', '2016 ~ 2024', '2018 ~ 2021',
#        '2009 ~ 2024', '2007 ~ 2022', 'Jun 30, 2021 On Loan',
# ...

# %% [markdown]
# ### Observaiton: this column is very messy an requires some outside the box solution
# ### Solution : Categorize the values into 'ON LOAN'; for players on loan, 'ACTIVE'; for players on contract and 'FREE';for free players

# %%
def contract(a):
    if 'On Loan' in a:
        a = 'ON LOAN'
        return a
    elif '~' in a:
        a = 'ACTIVE'
        return a
    elif 'Free' in a:
        a = 'FREE'
        return a

# %%
df.Contract = df.Contract.apply(contract)

# %%
df.Contract.unique()
# Out:
# array(['ACTIVE', 'ON LOAN', 'FREE'], dtype=object)

# %%
df.Contract = df.Contract.astype('category')

# %%
df = df.rename(columns={'Contract' : 'ContractStatus'})

# %%
df.head()
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            playerUrl Nationality  Age  OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33   93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35   92
# 2  http://sofifa.com/player/200389/jan-oblak/210006/    Slovenia   27   91
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium   29   91
# 4  http://sofifa.com/player/190871/neymar-da-silv...      Brazil   28   91
#
#    POT                 Club ContractStatus   Positions Height Weight  \
# 0   93         FC Barcelona         ACTIVE  RW, ST, CF  170cm   72kg
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 75 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   FullName          18979 non-null  object
#  3   playerUrl         18979 non-null  object
#  4   Nationality       18979 non-null  object
#  5   Age               18979 non-null  int64
#  6   OVA               18979 non-null  int64
#  7   POT               18979 non-null  int64
#  8   Club              18979 non-null  object
#  9   ContractStatus    18979 non-null  category
#  10  Positions         18979 non-null  object
#  11  Height            18979 non-null  object
#  12  Weight            18979 non-null  object
#  13  Preferred Foot    18979 non-null  object
#  14  BOV               18979 non-null  int64
#  15  Best Position     18979 non-null  object
# ...

# %% [markdown]
# #

# %% [markdown]
# ## Cleaning the Hits column

# %%
df.Hits.unique()
# Out:
# array(['771', '562', '150', '207', '595', '248', '246', '120', '1.6K',
#        '130', '321', '189', '175', '96', '118', '216', '212', '154',
#        '205', '202', '339', '408', '103', '332', '86', '173', '161',
#        '396', '1.1K', '433', '242', '206', '177', '1.5K', '198', '459',
#        '117', '119', '209', '84', '187', '165', '203', '65', '336', '126',
#        '313', '124', '145', '538', '182', '101', '45', '377', '99', '194',
#        '403', '414', '593', '374', '245', '3.2K', '266', '299', '309',
#        '215', '265', '211', '112', '337', '70', '159', '688', '116', '63',
#        '144', '123', '71', '224', '113', '168', '61', '89', '137', '278',
#        '75', '148', '176', '197', '264', '214', '247', '402', '440',
#        '1.7K', '2.3K', '171', '320', '657', '87', '259', '200', '255',
#        '253', '196', '60', '97', '85', '169', '256', '132', '239', '166',
#        '121', '109', '32', '46', '122', '48', '527', '199', '282', '51',
# ...

# %% [markdown]
# ### problem :some values  are written with 'k' to sgnify thaousand
# ### solution: change it to its actual numerical digits

# %%
# function that replaces the 'k' with an empty string and cast the value to a float so it can be multiplied by 1000 and return its numerical digits

def hitChange(h):
    if 'K' in h:
        h = h.replace('K', "")
        h = float(h)* 1000
        return round(h)
    else:
        return h

# %%
df.Hits = df.Hits.apply(hitChange)

# %%
df.Hits.unique()
# Out:
# array(['771', '562', '150', '207', '595', '248', '246', '120', 1600,
#        '130', '321', '189', '175', '96', '118', '216', '212', '154',
#        '205', '202', '339', '408', '103', '332', '86', '173', '161',
#        '396', 1100, '433', '242', '206', '177', 1500, '198', '459', '117',
#        '119', '209', '84', '187', '165', '203', '65', '336', '126', '313',
#        '124', '145', '538', '182', '101', '45', '377', '99', '194', '403',
#        '414', '593', '374', '245', 3200, '266', '299', '309', '215',
#        '265', '211', '112', '337', '70', '159', '688', '116', '63', '144',
#        '123', '71', '224', '113', '168', '61', '89', '137', '278', '75',
#        '148', '176', '197', '264', '214', '247', '402', '440', 1700, 2300,
#        '171', '320', '657', '87', '259', '200', '255', '253', '196', '60',
#        '97', '85', '169', '256', '132', '239', '166', '121', '109', '32',
#        '46', '122', '48', '527', '199', '282', '51', 1900, '642', '155',
# ...

# %%
df.head()
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            playerUrl Nationality  Age  OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33   93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35   92
# 2  http://sofifa.com/player/200389/jan-oblak/210006/    Slovenia   27   91
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium   29   91
# 4  http://sofifa.com/player/190871/neymar-da-silv...      Brazil   28   91
#
#    POT                 Club ContractStatus   Positions Height Weight  \
# 0   93         FC Barcelona         ACTIVE  RW, ST, CF  170cm   72kg
# ...

# %% [markdown]
# ## Cleaning the height and weight column

# %%
df.Height.unique()
# Out:
# array(['170cm', '187cm', '188cm', '181cm', '175cm', '184cm', '191cm',
#        '178cm', '193cm', '185cm', '199cm', '173cm', '168cm', '176cm',
#        '177cm', '183cm', '180cm', '189cm', '179cm', '195cm', '172cm',
#        '182cm', '186cm', '192cm', '165cm', '194cm', '167cm', '196cm',
#        '163cm', '190cm', '174cm', '169cm', '171cm', '197cm', '200cm',
#        '166cm', '6\'2"', '164cm', '198cm', '6\'3"', '6\'5"', '5\'11"',
#        '6\'4"', '6\'1"', '6\'0"', '5\'10"', '5\'9"', '5\'6"', '5\'7"',
#        '5\'4"', '201cm', '158cm', '162cm', '161cm', '160cm', '203cm',
#        '157cm', '156cm', '202cm', '159cm', '206cm', '155cm'], dtype=object)

# %%
def convert_height(x):
    if x[-1] == '"':
        x = x.replace("\"", "")
        inch = int(x[2:]) * 2.54
        foot = int(x[0]) * 30.48
        return round(foot+inch)
    elif x[-1] == "m":
        return int(x[:-2])

# %%
df.Height = df.Height.apply(convert_height)

# %%
df.Height.unique()
# Out:
# array([170, 187, 188, 181, 175, 184, 191, 178, 193, 185, 199, 173, 168,
#        176, 177, 183, 180, 189, 179, 195, 172, 182, 186, 192, 165, 194,
#        167, 196, 163, 190, 174, 169, 171, 197, 200, 166, 164, 198, 201,
#        158, 162, 161, 160, 203, 157, 156, 202, 159, 206, 155])

# %%
df = df.rename(columns={'Height':'Height_cm'})

# %%
df.head()
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            playerUrl Nationality  Age  OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33   93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35   92
# 2  http://sofifa.com/player/200389/jan-oblak/210006/    Slovenia   27   91
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium   29   91
# 4  http://sofifa.com/player/190871/neymar-da-silv...      Brazil   28   91
#
#    POT                 Club ContractStatus   Positions  Height_cm Weight  \
# 0   93         FC Barcelona         ACTIVE  RW, ST, CF        170   72kg
# ...

# %%
df.Weight.unique()
# Out:
# array(['72kg', '83kg', '87kg', '70kg', '68kg', '80kg', '71kg', '91kg',
#        '73kg', '85kg', '92kg', '69kg', '84kg', '96kg', '81kg', '82kg',
#        '75kg', '86kg', '89kg', '74kg', '76kg', '64kg', '78kg', '90kg',
#        '66kg', '60kg', '94kg', '79kg', '67kg', '65kg', '59kg', '61kg',
#        '93kg', '88kg', '97kg', '77kg', '62kg', '63kg', '95kg', '100kg',
#        '58kg', '183lbs', '179lbs', '172lbs', '196lbs', '176lbs', '185lbs',
#        '170lbs', '203lbs', '168lbs', '161lbs', '146lbs', '130lbs',
#        '190lbs', '174lbs', '148lbs', '165lbs', '159lbs', '192lbs',
#        '181lbs', '139lbs', '154lbs', '157lbs', '163lbs', '98kg', '103kg',
#        '99kg', '102kg', '56kg', '101kg', '57kg', '55kg', '104kg', '107kg',
#        '110kg', '53kg', '50kg', '54kg', '52kg'], dtype=object)

# %%
def weight_kg(x):
    if 'lbs' in x:
        x = x.replace('lbs', '')
        x = float(x) * 0.45359237
        x = int(x)
        return x
    else:
        return int(x[:-2])

# %%
df.Weight = df.Weight.apply(weight_kg)

# %%
df.Weight.unique()
# Out:
# array([ 72,  83,  87,  70,  68,  80,  71,  91,  73,  85,  92,  69,  84,
#         96,  81,  82,  75,  86,  89,  74,  76,  64,  78,  90,  66,  60,
#         94,  79,  67,  65,  59,  61,  93,  88,  97,  77,  62,  63,  95,
#        100,  58,  98, 103,  99, 102,  56, 101,  57,  55, 104, 107, 110,
#         53,  50,  54,  52])

# %%
df = df.rename(columns={'Weight':'Weight_kg'})

# %%
df.head()
# Out:
#        ID               Name                      FullName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            playerUrl Nationality  Age  OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33   93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35   92
# 2  http://sofifa.com/player/200389/jan-oblak/210006/    Slovenia   27   91
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium   29   91
# 4  http://sofifa.com/player/190871/neymar-da-silv...      Brazil   28   91
#
#    POT                 Club ContractStatus   Positions  Height_cm  Weight_kg  \
# 0   93         FC Barcelona         ACTIVE  RW, ST, CF        170         72
# ...

# %%
df.drop('playerUrl', axis = 1, inplace = True)

# %%
df.drop('Name', axis = 1, inplace = True)

# %%
df.head()
# Out:
#        ID                      FullName Nationality  Age  OVA  POT  \
# 0  158023                  Lionel Messi   Argentina   33   93   93
# 1   20801  C. Ronaldo dos Santos Aveiro    Portugal   35   92   92
# 2  200389                     Jan Oblak    Slovenia   27   91   93
# 3  192985               Kevin De Bruyne     Belgium   29   91   91
# 4  190871    Neymar da Silva Santos Jr.      Brazil   28   91   91
#
#                   Club ContractStatus   Positions  Height_cm  Weight_kg  \
# 0         FC Barcelona         ACTIVE  RW, ST, CF        170         72
# 1             Juventus         ACTIVE      ST, LW        187         83
# 2      Atlético Madrid         ACTIVE          GK        188         87
# 3      Manchester City         ACTIVE     CAM, CM        181         70
# 4  Paris Saint-Germain         ACTIVE     LW, CAM        175         68
#
#   Preferred Foot  BOV Best Position        Joined    Value      Wage  \
# ...

# %% [markdown]
# ## Change the joined column into a date time data type

# %%
df['Joined'] = pd.to_datetime(df['Joined'])

# %%
df.Joined
# Out:
# 0       2004-07-01
# 1       2018-07-10
# 2       2014-07-16
# 3       2015-08-30
# 4       2017-08-03
#            ...
# 18974   2018-07-13
# 18975   2020-08-01
# 18976   2019-03-08
# 18977   2020-09-22
# 18978   2019-07-29
# Name: Joined, Length: 18979, dtype: datetime64[ns]

# %%
df.head()
# Out:
#        ID                      FullName Nationality  Age  OVA  POT  \
# 0  158023                  Lionel Messi   Argentina   33   93   93
# 1   20801  C. Ronaldo dos Santos Aveiro    Portugal   35   92   92
# 2  200389                     Jan Oblak    Slovenia   27   91   93
# 3  192985               Kevin De Bruyne     Belgium   29   91   91
# 4  190871    Neymar da Silva Santos Jr.      Brazil   28   91   91
#
#                   Club ContractStatus   Positions  Height_cm  Weight_kg  \
# 0         FC Barcelona         ACTIVE  RW, ST, CF        170         72
# 1             Juventus         ACTIVE      ST, LW        187         83
# 2      Atlético Madrid         ACTIVE          GK        188         87
# 3      Manchester City         ACTIVE     CAM, CM        181         70
# 4  Paris Saint-Germain         ACTIVE     LW, CAM        175         68
#
#   Preferred Foot  BOV Best Position     Joined    Value      Wage  \
# ...

# %% [markdown]
# # CLeaning Value, Wage and Release Clause columns

# %% [markdown]
# ### Release clause

# %%
df['Release Clause'].unique()
# Out:
# array(['€138.4M', '€75.9M', '€159.4M', ..., '€59K', '€35K', '€64K'],
#       shape=(1216,), dtype=object)

# %%
def release(x):
    if 'M' in x:
        x = x.replace('M', '')
        x = float(x[1:])*1000000
        return round(x)
    elif 'K' in x:
        x = x.replace('K', '')
        x = float(x[1:])*1000
        return round(x)
    else:
        return x

# %%
df['Release Clause'] = df['Release Clause'].apply(release)

# %%
df['Release Clause'].unique()
# Out:
# array([138400000, 75900000, 159400000, ..., 59000, 35000, 64000],
#       shape=(1216,), dtype=object)

# %%
df = df.rename(columns={'Release Clause':'Release Clause €'})

# %%
df.head()
# Out:
#        ID                      FullName Nationality  Age  OVA  POT  \
# 0  158023                  Lionel Messi   Argentina   33   93   93
# 1   20801  C. Ronaldo dos Santos Aveiro    Portugal   35   92   92
# 2  200389                     Jan Oblak    Slovenia   27   91   93
# 3  192985               Kevin De Bruyne     Belgium   29   91   91
# 4  190871    Neymar da Silva Santos Jr.      Brazil   28   91   91
#
#                   Club ContractStatus   Positions  Height_cm  Weight_kg  \
# 0         FC Barcelona         ACTIVE  RW, ST, CF        170         72
# 1             Juventus         ACTIVE      ST, LW        187         83
# 2      Atlético Madrid         ACTIVE          GK        188         87
# 3      Manchester City         ACTIVE     CAM, CM        181         70
# 4  Paris Saint-Germain         ACTIVE     LW, CAM        175         68
#
#   Preferred Foot  BOV Best Position     Joined    Value      Wage  \
# ...

# %% [markdown]
# ### Wage

# %%
df.Wage.unique()
# Out:
# array(['€5601000', '€2201000', '€1251000', '€3701000', '€2701000',
#        '€2401000', '€2501000', '€1601000', '€2601000', '€2101000',
#        '€3101000', '€1301000', '€3501000', '€3001000', '€1901000',
#        '€1451000', '€1951000', '€1001000', '€1401000', '€2901000',
#        '€821000', '€1101000', '€2301000', '€1551000', '€2001000',
#        '€1651000', '€951000', '€1701000', '€1051000', '€1151000',
#        '€1501000', '€1351000', '€551000', '€581000', '€811000', '€341000',
#        '€1201000', '€591000', '€901000', '€651000', '€561000', '€711000',
#        '€181000', '€751000', '€471000', '€201000', '€841000', '€861000',
#        '€741000', '€781000', '€271000', '€681000', '€851000', '€251000',
#        '€461000', '€831000', '€541000', '€791000', '€1751000', '€431000',
#        '€491000', '€451000', '€381000', '€411000', '€391000', '€231000',
#        '€511000', '€501000', '€871000', '€301000', '€141000', '€691000',
# ...

# %%
def wage(x):
    if '€' in x:
        x = x.replace('€', '')
        return x

# %%
df.Wage = df.Wage.apply(wage)

# %%
df.Wage.unique()
# Out:
# array(['5601000', '2201000', '1251000', '3701000', '2701000', '2401000',
#        '2501000', '1601000', '2601000', '2101000', '3101000', '1301000',
#        '3501000', '3001000', '1901000', '1451000', '1951000', '1001000',
#        '1401000', '2901000', '821000', '1101000', '2301000', '1551000',
#        '2001000', '1651000', '951000', '1701000', '1051000', '1151000',
#        '1501000', '1351000', '551000', '581000', '811000', '341000',
#        '1201000', '591000', '901000', '651000', '561000', '711000',
#        '181000', '751000', '471000', '201000', '841000', '861000',
#        '741000', '781000', '271000', '681000', '851000', '251000',
#        '461000', '831000', '541000', '791000', '1751000', '431000',
#        '491000', '451000', '381000', '411000', '391000', '231000',
#        '511000', '501000', '871000', '301000', '141000', '691000',
#        '311000', '641000', '531000', '351000', '211000', '281000',
#        '171000', '331000', '701000', '321000', '891000', '261000',
# ...

# %%
df = df.rename(columns={'Wage': 'Wage €'})

# %%
df.head()
# Out:
#        ID                      FullName Nationality  Age  OVA  POT  \
# 0  158023                  Lionel Messi   Argentina   33   93   93
# 1   20801  C. Ronaldo dos Santos Aveiro    Portugal   35   92   92
# 2  200389                     Jan Oblak    Slovenia   27   91   93
# 3  192985               Kevin De Bruyne     Belgium   29   91   91
# 4  190871    Neymar da Silva Santos Jr.      Brazil   28   91   91
#
#                   Club ContractStatus   Positions  Height_cm  Weight_kg  \
# 0         FC Barcelona         ACTIVE  RW, ST, CF        170         72
# 1             Juventus         ACTIVE      ST, LW        187         83
# 2      Atlético Madrid         ACTIVE          GK        188         87
# 3      Manchester City         ACTIVE     CAM, CM        181         70
# 4  Paris Saint-Germain         ACTIVE     LW, CAM        175         68
#
#   Preferred Foot  BOV Best Position     Joined    Value   Wage €  \
# ...

# %% [markdown]
# ### Value

# %%
df.Value.unique()
# Out:
# array(['€103.5M', '€63M', '€120M', '€129M', '€132M', '€111M', '€120.5M',
#        '€102M', '€185.5M', '€110M', '€113M', '€90.5M', '€82M', '€17.5M',
#        '€83.5M', '€33.5M', '€114.5M', '€78M', '€103M', '€109M', '€92M',
#        '€10M', '€76.5M', '€89.5M', '€87.5M', '€79.5M', '€124M', '€114M',
#        '€95M', '€92.5M', '€105.5M', '€88.5M', '€85M', '€81.5M', '€26M',
#        '€21M', '€56M', '€67.5M', '€53M', '€36.5M', '€51M', '€65.5M',
#        '€46.5M', '€61.5M', '€72.5M', '€77.5M', '€43.5M', '€32.5M', '€36M',
#        '€32M', '€54M', '€49.5M', '€57M', '€66.5M', '€74.5M', '€71.5M',
#        '€121M', '€99M', '€67M', '€86.5M', '€93.5M', '€70M', '€62M',
#        '€66M', '€58M', '€44M', '€81M', '€37M', '€14.5M', '€46M', '€47.5M',
#        '€52.5M', '€54.5M', '€34.5M', '€57.5M', '€51.5M', '€44.5M', '€55M',
#        '€48M', '€60.5M', '€63.5M', '€61M', '€29M', '€58.5M', '€55.5M',
#        '€42M', '€40.5M', '€43M', '€45.5M', '€34M', '€26.5M', '€42.5M',
# ...

# %%
def value(x):
    if 'M' in x:
        x  = x.replace('M', '')
        x  = float(x[1:])*1000000
        return round(x)
    elif 'K' in x:
        x  = x.replace('K', '')
        x  = float(x[1:])*1000
        return round(x)
    else:
        return int(x[1:])

# %%
df.Value = df.Value.apply(value)

# %%
df.Value.unique()
# Out:
# array([103500000,  63000000, 120000000, 129000000, 132000000, 111000000,
#        120500000, 102000000, 185500000, 110000000, 113000000,  90500000,
#         82000000,  17500000,  83500000,  33500000, 114500000,  78000000,
#        103000000, 109000000,  92000000,  10000000,  76500000,  89500000,
#         87500000,  79500000, 124000000, 114000000,  95000000,  92500000,
#        105500000,  88500000,  85000000,  81500000,  26000000,  21000000,
#         56000000,  67500000,  53000000,  36500000,  51000000,  65500000,
#         46500000,  61500000,  72500000,  77500000,  43500000,  32500000,
#         36000000,  32000000,  54000000,  49500000,  57000000,  66500000,
#         74500000,  71500000, 121000000,  99000000,  67000000,  86500000,
#         93500000,  70000000,  62000000,  66000000,  58000000,  44000000,
#         81000000,  37000000,  14500000,  46000000,  47500000,  52500000,
#         54500000,  34500000,  57500000,  51500000,  44500000,  55000000,
# ...

# %%
df.head()
# Out:
#        ID                      FullName Nationality  Age  OVA  POT  \
# 0  158023                  Lionel Messi   Argentina   33   93   93
# 1   20801  C. Ronaldo dos Santos Aveiro    Portugal   35   92   92
# 2  200389                     Jan Oblak    Slovenia   27   91   93
# 3  192985               Kevin De Bruyne     Belgium   29   91   91
# 4  190871    Neymar da Silva Santos Jr.      Brazil   28   91   91
#
#                   Club ContractStatus   Positions  Height_cm  Weight_kg  \
# 0         FC Barcelona         ACTIVE  RW, ST, CF        170         72
# 1             Juventus         ACTIVE      ST, LW        187         83
# 2      Atlético Madrid         ACTIVE          GK        188         87
# 3      Manchester City         ACTIVE     CAM, CM        181         70
# 4  Paris Saint-Germain         ACTIVE     LW, CAM        175         68
#
#   Preferred Foot  BOV Best Position     Joined      Value   Wage €  \
# ...

# %%
df = df.rename(columns={'Value' : 'Value €'})

# %%
df.head()
# Out:
#        ID                      FullName Nationality  Age  OVA  POT  \
# 0  158023                  Lionel Messi   Argentina   33   93   93
# 1   20801  C. Ronaldo dos Santos Aveiro    Portugal   35   92   92
# 2  200389                     Jan Oblak    Slovenia   27   91   93
# 3  192985               Kevin De Bruyne     Belgium   29   91   91
# 4  190871    Neymar da Silva Santos Jr.      Brazil   28   91   91
#
#                   Club ContractStatus   Positions  Height_cm  Weight_kg  \
# 0         FC Barcelona         ACTIVE  RW, ST, CF        170         72
# 1             Juventus         ACTIVE      ST, LW        187         83
# 2      Atlético Madrid         ACTIVE          GK        188         87
# 3      Manchester City         ACTIVE     CAM, CM        181         70
# 4  Paris Saint-Germain         ACTIVE     LW, CAM        175         68
#
#   Preferred Foot  BOV Best Position     Joined    Value €   Wage €  \
# ...

# %% [markdown]
# # Exporting cleaned FIFA dataset

# %%
df.to_csv('new_Clean_FIFA_dataset.csv', index=False)
